# %%
pip install tavily-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://oneartifactoryprod.verizon.com/artifactory/api/pypi/Pypi-remote/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tavily import TavilyClient

tavily_client = TavilyClient(api_key="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")

response = tavily_client.extract("https://www.straighttalk.com/support/terms-conditions/")

response = tavily_client.extract("https://www.straighttalk.com/privacy-policy/") 
print(response)
# Out:
# {'results': [{'url': 'https://www.straighttalk.com/privacy-policy/', 'raw_content': 'Plans & Services\n\nShop for plans and services\n\nSERVICE PLANS\n\nDevice Plans\n\nHANDSET PROTECTION\n\nSTRAIGHT TALK EXTRAS\n\nPhones & Devices\n\nShop for phones, devices, accessories or bring your own device\n\nPHONES\n\nDevices\n\nAccessories\n\nMore Options\n\nDeals & Bundles\n\nGet the Best Deals in Wireless\n\nDeals\n\nRefill\n\nEnroll in Auto Pay or refill your service now\n\nRefill\n\nPrivacy Policy\n\nPrivacy Policy\n\nEffective Date: December, 2024\n\nIntroduction\n\nThis Privacy Policy applies to all TracFone brands including Total Wireless, Straight Talk Wireless, Tracfone, Simple Mobile, SafeLink Wireless, Walmart Family Mobile, Net10 Wireless, Page Plus, GoSmart Mobile, and Clearway Wireless for Business. TracFone is a Verizon company.\n\nOur Privacy Policy describes the information that we collect, how it’s used, shared, and retained, your choices about how it’s used and shared, and
# ...

# %%
response.keys()
# Out:
# dict_keys(['results', 'failed_results', 'response_time'])

# %%
response['results'][0].keys()
# Out:
# dict_keys(['url', 'raw_content', 'images'])

# %%
print(response['results'][0]['raw_content'])
# Out:
# Plans & Services
#
# Shop for plans and services
#
# SERVICE PLANS
#
# Device Plans
#
# HANDSET PROTECTION
#
# STRAIGHT TALK EXTRAS
#
# Phones & Devices
#
# Shop for phones, devices, accessories or bring your own device
#
# PHONES
#
# Devices
#
# Accessories
#
# More Options
#
# Deals & Bundles
#
# Get the Best Deals in Wireless
#
# Deals
#
# Refill
#
# Enroll in Auto Pay or refill your service now
#
# Refill
#
# Privacy Policy
#
# Privacy Policy
#
# Effective Date: December, 2024
#
# Introduction
#
# This Privacy Policy applies to all TracFone brands including Total Wireless, Straight Talk Wireless, Tracfone, Simple Mobile, SafeLink Wireless, Walmart Family Mobile, Net10 Wireless, Page Plus, GoSmart Mobile, and Clearway Wireless for Business. TracFone is a Verizon company.
#
# ...

# %%
data = response['results'][0]['raw_content']
print(len(data))
# Out:
# 58710

# %%
with open("Privacy_policy_Extracted.txt", "w") as file:
    file.write(data)

# %%
# Documentation: 
# https://docs.tavily.com/sdk/python/quick-start
